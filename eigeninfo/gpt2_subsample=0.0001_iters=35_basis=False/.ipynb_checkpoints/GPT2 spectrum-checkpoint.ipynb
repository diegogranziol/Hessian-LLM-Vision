# %%
import torch
import os
os.listdir('.')
# Out:
# ['Untitled.ipynb', 'results.ckpt', '.ipynb_checkpoints']

# %%
ckpt = torch.load("results.ckpt")

# %%
eigvals = ckpt['eigvals']
gammas = ckpt['gammas']

# %%
import matplotlib.pyplot as plt

# Assuming 'eigvals' and 'gammas' are already computed as shown in previous discussions
plt.figure(figsize=(10, 6))
(markerline, stemlines, baseline) = plt.stem(eigvals.cpu().numpy(), gammas.cpu().numpy(), use_line_collection=True)
plt.setp(markerline, color='b', marker='o')  # Blue markers
plt.setp(stemlines, color='r')  # Red stems
plt.setp(baseline, visible=False)  # Hide the baseline

plt.title('Spectral Density vs Eigenvalues')
plt.xlabel('Eigenvalues')
plt.ylabel('Spectral Density (Gammas)')
plt.yscale('log')
plt.grid(True)
plt.show()
# Out:
# /var/folders/6x/968yrv5913bf3cjf51gcdxvw0000gn/T/ipykernel_4226/1353468747.py:5: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   (markerline, stemlines, baseline) = plt.stem(eigvals.cpu().numpy(), gammas.cpu().numpy(), use_line_collection=True)

# %%
torch.dot(eigvals,gammas)
# Out:
# tensor(-1.7625e-07)
